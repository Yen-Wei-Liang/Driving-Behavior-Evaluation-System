# %%
import Data_Engineering
import pandas as pd

Preprocessing   = Data_Engineering.Preprocessing()
DataSet         = pd.read_csv(r'C:\Users\William\Desktop\可愛的論文之一\2.程式\Raw_DataSet_Label.csv')
Train_Data      = pd.read_csv(r'C:\Users\William\Desktop\可愛的論文之一\2.程式\Train_DataSet_Rotation_Init_Normalized_Cluster.csv')
Test_Data       = pd.read_csv(r'C:\Users\William\Desktop\可愛的論文之一\2.程式\Test_DataSet_Rotation_Init_Normalized_Cluster.csv')
Validation_Data = pd.read_csv(r'C:\Users\William\Desktop\可愛的論文之一\2.程式\Validation_DataSet_Rotation_Init_Normalized_Cluster.csv')
# Out:
# C:\Users\William\AppData\Local\Temp\ipykernel_15056\4002837465.py:8: DtypeWarning: Columns (60) have mixed types. Specify dtype option on import or set low_memory=False.
#   Validation_Data = pd.read_csv(r'C:\Users\William\Desktop\可愛的論文之一\2.程式\Validation_DataSet_Rotation_Init_Normalized_Cluster.csv')

# %%
###########################################################################
# 資料集簡介
#
# 檔案名稱      :Train_Data
# 資料集描述    :(時)2023年4月17日14時16分開始，(地)學校附近，(車人流量)少
# 總資料筆數    :27577筆
# 取樣頻率每秒  :30次
# 動作元素分群  :4群
# 標記狀況      :12983筆 
# 駕駛動作      :
#               直線: 8次
#               怠速: 21次
#               左轉: 6次
#               右轉: 6次
#               待轉: 11次
#               迴轉: 7次
#
# 檔案名稱      :Test_Data
# 資料集描述    :(時)2023年4月17日14時16分開始，(地)學校附近，(車人流量)少
# 總資料筆數    :27577筆
# 取樣頻率      :每秒30次
# 動作元素分群  : 4群
# 標記狀況      : 5774筆 
# 駕駛動作      :
#               直線: 6次
#               怠速: 10次
#               左轉: 4次
#               右轉: 4次
#               待轉: 5次
#               迴轉: 2次
#
# 檔案名稱      :Validation_DataSet
# 資料集描述    :(時)2023年5月30日18時00分開始，(地)忠孝夜市，(車人流量)高
# 總資料筆數    :28009筆 
# 取樣頻率      :每秒30次
# 動作元素分群  :4群
# 標記狀況      :7142筆  
###########################################################################

# %%
Preprocessing.Train_Vomm(Train_Data, 4)
# Out:
# 訓練模型所花費時間：0小時26分鐘17秒

# %%
Preprocessing.Test_Vomm(Test_Data, 30)
# Out:
# 預測所花費時間：0小時8分鐘1秒

# %%
Preprocessing.Compute_Accuracy(Test_Data, 30)
# Out:
#     Prediction  Match Percentage
# 0       Action        100.000000
# 1    length_30         72.878421
# 2    Filter_30         78.714929
# 3    length_60         71.735365
# 4    Filter_60         74.350537
# 5    length_90         69.674402
# 6    Filter_90         69.899550
# 7   length_120         64.807759
# 8   Filter_120         66.106685
# 9   length_150         60.980256
# 10  Filter_150         62.088673

# %%
Preprocessing.Plot_Action_Track(Test_Data, 'Filter_30')
# Out:
# 繪製動作序列所花費時間：0小時0分鐘9秒

# %%
Preprocessing.Validation_Vomm(Validation_Data, 30)
# Out:
# 預測所花費時間：0小時4分鐘45秒

# %%
Preprocessing.Compute_Accuracy(Validation_Data, 30)
# Out:
#     Prediction  Match Percentage
# 0       Action        100.000000
# 1    length_30         45.897508
# 2    Filter_30         52.226267
# 3    length_60         48.067768
# 4    Filter_60         52.520302
# 5    length_90         49.523943
# 6    Filter_90         51.694203
# 7   length_120         50.266032
# 8   Filter_120         52.660319
# 9   length_150         50.700084
# 10  Filter_150         51.596192

# %%
Preprocessing.Validation_Vomm(DataSet, 30)
# Out:
# 預測所花費時間：0小時12分鐘13秒

# %%
Preprocessing.Compute_Accuracy(DataSet, 30)
# Out:
#     Prediction  Match Percentage
# 0       Action        100.000000
# 1    length_30         75.094602
# 2    Filter_30         79.674106
# 3    length_60         74.681443
# 4    Filter_60         77.376631
# 5    length_90         72.646536
# 6    Filter_90         74.206502
# 7   length_120         69.576801
# 8   Filter_120         71.036373
# 9   length_150         66.777357
# 10  Filter_150         68.067032
