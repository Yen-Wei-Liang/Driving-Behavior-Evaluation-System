# %%
###########################################################################
# 資料集簡介
#
# 檔案名稱      ： Train_DataSet_Rotation_Init_Normalized_10_Cluster.csv
# 資料集描述    :(時)2023年4月17日14時16分開始，(地)學校附近，(車人流量)少
# 總資料筆數     : 27577筆  
# 取樣頻率      ： 每秒30次
# 動作元素分群  ： 10群
# 標記狀況      : 7338筆 
#
# 檔案名稱      : Test_DataSet_Rotation_Init_Normalized_10_Cluster.csv
# 資料集描述    :(時)2023年4月17日14時16分開始，(地)學校附近，(車人流量)少
# 總資料筆數    :27577筆
# 取樣頻率      :每秒30次
# 動作元素分群  :10群
# 標記狀況     : 11185筆 
#
#
# 個動作平均長度正負一個標準差
# 直行 : (56, 134)
# 待速 : (137, 268)
# 左轉 : (119, 145)
# 右轉 : (118, 143)
# 待轉 : (96, 126)
# 迴轉 : (84, 99)
#
#
# 檔案名稱      ： Train_DataSet_Rotation_Init_Normalized_4_Cluster.csv
# 資料集描述    :(時)2023年4月17日14時16分開始，(地)學校附近，(車人流量)少
# 總資料筆數     : 27577筆  
# 取樣頻率      ： 每秒30次
# 動作元素分群  ： 4群
# 標記狀況      : 7338筆 
#
# 檔案名稱      : Test_DataSet_Rotation_Init_Normalized_4_Cluster.csv
# 資料集描述    :(時)2023年4月17日14時16分開始，(地)學校附近，(車人流量)少
# 總資料筆數    :27577筆
# 取樣頻率      :每秒30次
# 動作元素分群  :4群
# 標記狀況     : 11185筆 
###########################################################################

# %%
###########################################################################################################################
# 實驗一       : 使用　RideTrack 
# 訓練資料集   : Train_DataSet_Rotation_Init_Normalized_10_Cluster.csv
# 測試資料集   : Test_DataSet_Rotation_Init_Normalized_10_Cluster.csv
# 取樣頻率     : 30
# 動作元素分群 : 10
# 整體準確度   : 72%
#
# 補充說明
# RideTrack            Idle        U-turn    Two-Stage Left    Turn Right    Turn Left    Go Straight    Match Percentage
# Predict           93.863934    60.480349    38.219424        24.303797    32.748538    44.536082        80.500671
# Filter_Predict    98.796616    70.960699    61.780576        20.506329    29.239766    63.505155        87.554761
###########################################################################################################################

# %%
import Ridetrack_Analysis
import pandas as pd

RideTrackAnalyzer   = Ridetrack_Analysis.RideTrackAnalyzer()
Train_Data      = pd.read_csv('Train_DataSet_Rotation_Init_Normalized_10_Cluster.csv')
Test_Data       = pd.read_csv('Test_DataSet_Rotation_Init_Normalized_10_Cluster.csv')

# %%
RideTrackAnalyzer.Train_Vomm(Train_Data, 24, 10)
RideTrackAnalyzer.Test_Vomm(Test_Data, 30)
RideTrackAnalyzer.Compute_Accuracy_V3(Test_Data, 30)
# Out:
# 訓練模型所花費時間：0小時0分鐘29秒
# 100%|██████████████████████████████████████████████████████████████████████████| 27577/27577 [1:10:16<00:00,  6.54it/s]
# 預測所花費時間：1小時10分鐘16秒
#         RideTrack        Idle      U-turn  Two-Stage Left  Turn Right  \
# 0          Action  100.000000  100.000000      100.000000  100.000000
# 1         Predict   85.178125   22.270742       33.543165   53.924051
# 2  Filter_Predict   86.274276   22.270742       38.039568   53.417722
#
#     Turn Left  Go Straight  Match Percentage
# 0  100.000000   100.000000        100.000000
# 1   22.222222    20.824742         71.649531
# 2   22.222222    12.371134         72.534645

# %%
RideTrackAnalyzer.Plot_Action_Cluter(Train_Data, 'Turn Right', 'Turn Left', 'Z-axis Angular Velocity', 10, 150)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# ...

# %%
########################################################################################
# 實驗二       : 使用　RideTrack 
# 訓練資料集   : Train_DataSet_Rotation_Init_Normalized_10_Cluster.csv
# 測試資料集   : Test_DataSet_Rotation_Init_Normalized_10_Cluster.csv
# 取樣頻率     : 10
# 動作元素分群 : 10
# 整體準確度   : 69%
########################################################################################

# %%
import Ridetrack_Analysis
import pandas as pd

RideTrackAnalyzer   = Ridetrack_Analysis.RideTrackAnalyzer()
Train_Data      = pd.read_csv('Train_DataSet_Rotation_Init_Normalized_10_Cluster.csv')
Test_Data       = pd.read_csv('Test_DataSet_Rotation_Init_Normalized_10_Cluster.csv')
Train_Data = Train_Data[::3]
Test_Data  = Test_Data[::3]

# %%
RideTrackAnalyzer.Train_Vomm(Train_Data, 24, 10)
RideTrackAnalyzer.Test_Vomm(Test_Data, 10)
RideTrackAnalyzer.Compute_Accuracy_V3(Test_Data, 10)
# Out:
# 訓練模型所花費時間：0小時0分鐘4秒
# 100%|██████████████████████████████████████████████████████████████████████████████| 9193/9193 [02:06<00:00, 72.88it/s]
# 預測所花費時間：0小時2分鐘6秒
#         RideTrack        Idle      U-turn  Two-Stage Left  Turn Right  \
# 0          Action  100.000000  100.000000      100.000000  100.000000
# 1         Predict   79.671311   33.986928       28.997290   30.534351
# 2  Filter_Predict   80.600214   39.215686       33.604336   30.534351
#
#     Turn Left  Go Straight  Match Percentage
# 0  100.000000   100.000000        100.000000
# 1   22.123894    32.298137         67.257112
# 2   23.893805    41.614907         69.082126

# %%
RideTrackAnalyzer.Plot_Action_Cluter(Train_Data, 'Turn Right', 'Turn Left', 'Z-axis Angular Velocity', 10, 50)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# ...

# %%
########################################################################################
# 實驗三       : 使用　RideTrack 
# 訓練資料集   : Train_DataSet_Rotation_Init_Normalized_10_Cluster.csv
# 測試資料集   : Test_DataSet_Rotation_Init_Normalized_10_Cluster.csv
# 取樣頻率     : 6
# 動作元素分群 : 10
# 整體準確度   : 70%
########################################################################################

# %%
import Ridetrack_Analysis
import pandas as pd

RideTrackAnalyzer   = Ridetrack_Analysis.RideTrackAnalyzer()
Train_Data      = pd.read_csv('Train_DataSet_Rotation_Init_Normalized_10_Cluster.csv')
Test_Data       = pd.read_csv('Test_DataSet_Rotation_Init_Normalized_10_Cluster.csv')
Train_Data = Train_Data[::5]
Test_Data  = Test_Data[::5]

# %%
RideTrackAnalyzer.Train_Vomm(Train_Data, 24, 10)
RideTrackAnalyzer.Test_Vomm(Test_Data, 6)
RideTrackAnalyzer.Compute_Accuracy_V3(Test_Data, 6)
# Out:
# 訓練模型所花費時間：0小時0分鐘2秒
# 100%|█████████████████████████████████████████████████████████████████████████████| 5516/5516 [00:23<00:00, 231.85it/s]
# 預測所花費時間：0小時0分鐘23秒
#         RideTrack        Idle      U-turn  Two-Stage Left  Turn Right  \
# 0          Action  100.000000  100.000000      100.000000      100.00
# 1         Predict   82.093992   17.391304       29.864253       28.75
# 2  Filter_Predict   84.295062   22.826087       32.579186       30.00
#
#     Turn Left  Go Straight  Match Percentage
# 0  100.000000   100.000000        100.000000
# 1   23.529412    30.612245         68.348214
# 2   26.470588    30.612245         70.625000

# %%
RideTrackAnalyzer.Plot_Action_Cluter(Train_Data, 'Turn Right', 'Turn Left', 'Z-axis Angular Velocity', 10, 30)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# ...

# %%
########################################################################################
# 實驗四       : 使用　RideTrack 
# 訓練資料集   : Train_DataSet_Rotation_Init_Normalized_4_Cluster.csv
# 測試資料集   : Test_DataSet_Rotation_Init_Normalized_4_Cluster.csv
# 取樣頻率     : 30
# 動作元素分群 : 4
# 整體準確度   : 
########################################################################################

# %%
import Ridetrack_Analysis
import pandas as pd

RideTrackAnalyzer   = Ridetrack_Analysis.RideTrackAnalyzer()
Train_Data      = pd.read_csv('Train_DataSet_Rotation_Init_Normalized_4_Cluster.csv')
Test_Data       = pd.read_csv('Test_DataSet_Rotation_Init_Normalized_4_Cluster.csv')

# %%
RideTrackAnalyzer.Train_Vomm(Train_Data, 24, 4)
RideTrackAnalyzer.Test_Vomm(Test_Data, 30)
RideTrackAnalyzer.Compute_Accuracy_V3(Test_Data, 30)
# Out:
# 訓練模型所花費時間：0小時0分鐘23秒
#  63%|██████████████████████████████████████████████▌                           | 17373/27577 [1:06:01<42:43,  3.98it/s]

# %%
RideTrackAnalyzer.Plot_Action_Cluter(Train_Data, 'Turn Right', 'Turn Left', 'Z-axis Angular Velocity', 4, 150)

# %%
########################################################################################
# 實驗五       : 使用　RideTrack 
# 訓練資料集   : Train_DataSet_Rotation_Init_Normalized_4_Cluster.csv
# 測試資料集   : Test_DataSet_Rotation_Init_Normalized_4_Cluster.csv
# 取樣頻率     : 10
# 動作元素分群 : 4
# 整體準確度   : 
########################################################################################

# %%
import Ridetrack_Analysis
import pandas as pd

RideTrackAnalyzer   = Ridetrack_Analysis.RideTrackAnalyzer()
Train_Data      = pd.read_csv('Train_DataSet_Rotation_Init_Normalized_4_Cluster.csv')
Test_Data       = pd.read_csv('Test_DataSet_Rotation_Init_Normalized_4_Cluster.csv')
Train_Data = Train_Data[::3]
Test_Data  = Test_Data[::3]

# %%
RideTrackAnalyzer.Train_Vomm(Train_Data, 24, 4)
RideTrackAnalyzer.Test_Vomm(Test_Data, 10)
RideTrackAnalyzer.Compute_Accuracy_V3(Test_Data, 10)

# %%
RideTrackAnalyzer.Plot_Action_Cluter(Train_Data, 'Turn Right', 'Turn Left', 'Z-axis Angular Velocity', 4, 50)

# %%
########################################################################################
# 實驗六       : 使用　RideTrack 
# 訓練資料集   : Train_DataSet_Rotation_Init_Normalized_4_Cluster.csv
# 測試資料集   : Test_DataSet_Rotation_Init_Normalized_4_Cluster.csv
# 取樣頻率     : 6
# 動作元素分群 : 4
# 整體準確度   : 
########################################################################################

# %%
import Ridetrack_Analysis
import pandas as pd

RideTrackAnalyzer   = Ridetrack_Analysis.RideTrackAnalyzer()
Train_Data      = pd.read_csv('Train_DataSet_Rotation_Init_Normalized_4_Cluster.csv')
Test_Data       = pd.read_csv('Test_DataSet_Rotation_Init_Normalized_4_Cluster.csv')
Train_Data = Train_Data[::5]
Test_Data  = Test_Data[::5]

# %%
RideTrackAnalyzer.Train_Vomm(Train_Data, 24, 4)
RideTrackAnalyzer.Test_Vomm(Test_Data, 6)
RideTrackAnalyzer.Compute_Accuracy_V3(Test_Data, 6)

# %%
RideTrackAnalyzer.Plot_Action_Cluter(Train_Data, 'Turn Right', 'Turn Left', 'Z-axis Angular Velocity', 4, 30)

# %%
########################################################################################
# 實驗七       : 使用　傳統閥值分類   (尚未完成)
# 訓練資料集   : Train_DataSet_Rotation_Init_Normalized_10_Cluster.csv
# 測試資料集   : Test_DataSet_Rotation_Init_Normalized_10_Cluster.csv
# 取樣頻率     : 30
# 每個特徵分   : 2群
# 整體準確度   : 
########################################################################################

# %%
import Ridetrack_Analysis
import pandas as pd

RideTrackAnalyzer   = Ridetrack_Analysis.RideTrackAnalyzer()
Train_Data      = pd.read_csv('Train_DataSet_Rotation_Init_Normalized_10_Cluster.csv')
Test_Data       = pd.read_csv('Test_DataSet_Rotation_Init_Normalized_10_Cluster.csv')

# %%
RideTrackAnalyzer.Tradition_Category(Test_Data, [0, 0.5, 1],['X-axis Angular Velocity', 'Y-axis Angular Velocity', 'Z-axis Angular Velocity', 'X-axis Acceleration', 'Y-axis Acceleration', 'Z-axis Acceleration', 'X-axis Angle', 'Y-axis Angle', 'Z-axis Angle'])
RideTrackAnalyzer.Tradition_Encoding(Test_Data, ['X-axis Angular Velocity_Category', 'Y-axis Angular Velocity_Category', 'Z-axis Angular Velocity_Category', 'X-axis Acceleration_Category', 'Y-axis Acceleration_Category', 'Z-axis Acceleration_Category', 'X-axis Angle_Category', 'Y-axis Angle_Category', 'Z-axis Angle_Category'])
RideTrackAnalyzer.Tradition_Find_Top_K(Test_Data, 70)

# %%
########################################################################################
# 實驗八       : 使用　傳統閥值分類
# 訓練資料集   : Train_DataSet_Rotation_Init_Normalized_10_Cluster.csv
# 測試資料集   : Test_DataSet_Rotation_Init_Normalized_10_Cluster.csv
# 取樣頻率     : 30
# 每個特徵分   : 3群
# 整體準確度   : 
########################################################################################

# %%
import Ridetrack_Analysis
import pandas as pd

RideTrackAnalyzer   = Ridetrack_Analysis.RideTrackAnalyzer()
Train_Data      = pd.read_csv('Train_DataSet_Rotation_Init_Normalized_10_Cluster.csv')
Test_Data       = pd.read_csv('Test_DataSet_Rotation_Init_Normalized_10_Cluster.csv')

# %%
RideTrackAnalyzer.Tradition_Category(Test_Data, [0, 0.33, 0.66, 1],['X-axis Angular Velocity', 'Y-axis Angular Velocity', 'Z-axis Angular Velocity', 'X-axis Acceleration', 'Y-axis Acceleration', 'Z-axis Acceleration', 'X-axis Angle', 'Y-axis Angle', 'Z-axis Angle'])
RideTrackAnalyzer.Tradition_Encoding(Test_Data, ['X-axis Angular Velocity_Category', 'Y-axis Angular Velocity_Category', 'Z-axis Angular Velocity_Category', 'X-axis Acceleration_Category', 'Y-axis Acceleration_Category', 'Z-axis Acceleration_Category', 'X-axis Angle_Category', 'Y-axis Angle_Category', 'Z-axis Angle_Category'])
RideTrackAnalyzer.Tradition_Find_Top_K(Test_Data, 70)

# %%
# 口試前準備：

# O 欲提口試者請上網至【教務資訊系統】，以個人學號和密碼登入，完成【碩（專）博士論文題目登錄】

# V 再於本校白天上班時間致電班級業務承辦人登記借用考試地點，並將「碩士論文考試申請書」填妥，

# V 檢附電腦打字填列之「教師擔任碩士班研究生論文口試明細表及聘函」

# V 校外口試委員之「個人身分證及局帳號資料表」

# O 105(含)學年度後入學者須另檢附「學術倫理教育修課證明」

# 於口試前一個月（註七）送交電機系辦

# 寄出紙本論文給口試委員時，務必先至系辦信箱領取口試委員聘函(系辦不會通知領取)，與紙本論文一併寄出，同時將聘書掃描成電子檔，連同論文pdf檔一併Email給口試委員，並告知紙本的論文及聘書已寄出。

# %%
# 黃教授

# 謝謝你的邀請, 我目前以下時段都可以, 但要麻煩你儘快確定時間, 因為同時有很多口試的邀請, 謝謝
# 7/24 (一) □ 08:30~12:00  □ 13:00~16:30

# 7/25 (二) □ 08:30~12:00  □ 13:00~16:30

# 7/26 (三) □ 08:30~12:00  □ 13:00~16:30

# 7/27 (四) □ 08:30~12:00  □ 13:00~16:30


# 溫教授

# 形式： 親自出席

# 地點：中興大學電機系館

# 下列位可以的口試時段:

# 7/24 (一) □ 13:00~16:30

# 7/25 (二) □ 08:30~12:00  □ 13:00~16:30

# 7/26 (三) □ 08:30~12:00  


# 若可以，請你儘早告知確定的日期和時間。








# 老師好，
# 謝謝您的回覆。
# 目前口試時間訂於：O/O（星期O）上午 O:OO，預計至O:OO  (約 X 小時)
# 地點：OOOOOOOO （地址：OOOOOOOOOOOO）

# 論文初稿將於O/OO（口試一週前）寄出。相關行政事項等所上公布後，再向您詢問及確認。
# 再次謝謝您撥冗前來指導。

# 祝
# 身體健康 萬事如意


# 學生 XXX 敬上
