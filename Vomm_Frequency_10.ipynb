# %%
import Data_Engineering
import pandas as pd

Preprocessing   = Data_Engineering.Preprocessing()
DataSet         = pd.read_csv(r'C:\Users\William\Desktop\可愛的論文之一\2.程式\Raw_DataSet_Label.csv')
Train_Data      = pd.read_csv(r'C:\Users\William\Desktop\可愛的論文之一\2.程式\Train_DataSet_Rotation_Init_Normalized_Cluster.csv')
Test_Data       = pd.read_csv(r'C:\Users\William\Desktop\可愛的論文之一\2.程式\Test_DataSet_Rotation_Init_Normalized_Cluster.csv')
Validation_Data = pd.read_csv(r'C:\Users\William\Desktop\可愛的論文之一\2.程式\Validation_DataSet_Rotation_Init_Normalized_Cluster.csv')
# Out:
# C:\Users\William\AppData\Local\Temp\ipykernel_16372\4002837465.py:8: DtypeWarning: Columns (60) have mixed types. Specify dtype option on import or set low_memory=False.
#   Validation_Data = pd.read_csv(r'C:\Users\William\Desktop\可愛的論文之一\2.程式\Validation_DataSet_Rotation_Init_Normalized_Cluster.csv')

# %%
###########################################################################
# 資料集簡介
#
# 檔案名稱      ： Train_Data
# 資料集描述    :(時)2023年4月17日14時16分開始，(地)學校附近，(車人流量)少
# 總資料筆數     : 9192筆  
# 取樣頻率      ： 每秒10次
# 動作元素分群  ： 4群
# 標記狀況      : 4327筆 
#
# 檔案名稱      :Test_Data
# 資料集描述    :(時)2023年4月17日14時16分開始，(地)學校附近，(車人流量)少
# 總資料筆數    :9192筆
# 取樣頻率      :每秒10次
# 動作元素分群  :4群
# 標記狀況     : 1924筆 
#
# 檔案名稱      :Validation_DataSet
# 資料集描述    :(時)2023年5月30日18時00分開始，(地)忠孝夜市，(車人流量)高
# 總資料筆數    :9336筆   #28009
# 取樣頻率      :每秒10次
# 動作元素分群  :4群
# 標記狀況     :2380筆 
###########################################################################

# %%
Train_Data      = Train_Data[::3]
Test_Data       = Test_Data[::3]
Validation_Data = Validation_Data[::3]

# %%
Preprocessing.Train_Vomm(Train_Data, 4)
# Out:
# 訓練模型所花費時間：0小時3分鐘4秒

# %%
Preprocessing.Test_Vomm(Test_Data, 10)
# Out:
# 預測所花費時間：0小時0分鐘28秒

# %%
Preprocessing.Compute_Accuracy(Test_Data, 10)
# Out:
#    Prediction  Match Percentage
# 0      Action        100.000000
# 1   length_10         72.689512
# 2   Filter_10         77.414330
# 3   length_20         66.147456
# 4   Filter_20         72.793354
# 5   length_30         61.526480
# 6   Filter_30         63.499481
# 7   length_40         60.280374
# 8   Filter_40         61.370717
# 9   length_50         56.490135
# 10  Filter_50         56.697819

# %%
Preprocessing.Plot_Action_Track(Test_Data, 'Filter_10')
# Out:
# 繪製動作序列所花費時間：0小時0分鐘3秒

# %%
Preprocessing.Validation_Vomm(Validation_Data, 10)
# Out:
# 預測所花費時間：0小時0分鐘26秒

# %%
Preprocessing.Compute_Accuracy(Validation_Data, 10)
# Out:
#    Prediction  Match Percentage
# 0      Action        100.000000
# 1   length_10         53.002940
# 2   Filter_10         53.002940
# 3   length_20         51.574969
# 4   Filter_20         52.960941
# 5   length_30         50.650987
# 6   Filter_30         51.154977
# 7   length_40         50.104998
# 8   Filter_40         51.154977
# 9   length_50         50.398992
# 10  Filter_50         51.028979

# %%
Preprocessing.Test_Vomm(DataSet, 10)
# Out:
# 預測所花費時間：0小時2分鐘35秒

# %%
Preprocessing.Compute_Accuracy(DataSet, 10)
# Out:
#    Prediction  Match Percentage
# 0      Action        100.000000
# 1   length_10         68.897212
# 2   Filter_10         72.017144
# 3   length_20         64.089891
# 4   Filter_20         70.148274
# 5   length_30         64.136227
# 6   Filter_30         67.769712
# 7   length_40         64.402657
# 8   Filter_40         67.082400
# 9   length_50         65.078384
# 10  Filter_50         67.225268
