# %%
import Data_Engineering
import pandas as pd

Preprocessing   = Data_Engineering.Preprocessing()
DataSet         = pd.read_csv(r'C:\Users\William\Desktop\可愛的論文之一\2.程式\Raw_DataSet_Label.csv')
Train_Data      = pd.read_csv(r'C:\Users\William\Desktop\可愛的論文之一\2.程式\Train_DataSet_Rotation_Init_Normalized_Cluster.csv')
Test_Data       = pd.read_csv(r'C:\Users\William\Desktop\可愛的論文之一\2.程式\Test_DataSet_Rotation_Init_Normalized_Cluster.csv')
Validation_Data = pd.read_csv(r'C:\Users\William\Desktop\可愛的論文之一\2.程式\Validation_DataSet_Rotation_Init_Normalized_Cluster.csv')
# Out:
# C:\Users\William\AppData\Local\Temp\ipykernel_21388\4002837465.py:8: DtypeWarning: Columns (60) have mixed types. Specify dtype option on import or set low_memory=False.
#   Validation_Data = pd.read_csv(r'C:\Users\William\Desktop\可愛的論文之一\2.程式\Validation_DataSet_Rotation_Init_Normalized_Cluster.csv')

# %%
###########################################################################
# 資料集簡介
#
# 檔案名稱      ： Train_Data
# 資料集描述    :(時)2023年4月17日14時16分開始，(地)學校附近，(車人流量)少
# 總資料筆數     : 5515筆
# 取樣頻率      ： 每秒6次
# 動作元素分群  ： 4群
# 標記狀況      : 2596筆   
#
# 檔案名稱      :Test_Data
# 資料集描述    :(時)2023年4月17日14時16分開始，(地)學校附近，(車人流量)少
# 總資料筆數    :5515筆
# 取樣頻率      :每秒6次
# 動作元素分群  :4群
# 標記狀況     : 1154筆    
#
# 檔案名稱      :Validation_DataSet
# 資料集描述    :(時)2023年5月30日18時00分開始，(地)忠孝夜市，(車人流量)高
# 總資料筆數    :5601筆
# 取樣頻率      :每秒6次
# 動作元素分群  :4群
# 標記狀況     :1428筆    
###########################################################################

# %%
Train_Data      = Train_Data[::5]
Test_Data       = Test_Data[::5]
Validation_Data = Validation_Data[::5]

# %%
Preprocessing.Train_Vomm(Train_Data, 6)
# Out:
# 訓練模型所花費時間：0小時1分鐘1秒

# %%
Preprocessing.Test_Vomm(Test_Data, 6)
# Out:
# 預測所花費時間：0小時0分鐘7秒

# %%
Preprocessing.Compute_Accuracy(Test_Data, 6)
# Out:
#    Prediction  Match Percentage
# 0      Action        100.000000
# 1    length_6         77.162630
# 2    Filter_6         79.325260
# 3   length_12         70.069204
# 4   Filter_12         76.557093
# 5   length_18         66.262976
# 6   Filter_18         71.799308
# 7   length_24         62.456747
# 8   Filter_24         64.532872
# 9   length_30         59.602076
# 10  Filter_30         61.159170

# %%
Preprocessing.Plot_Action_Track(Test_Data, 'Filter_12')
# Out:
# 繪製動作序列所花費時間：0小時0分鐘2秒

# %%
Preprocessing.Validation_Vomm(Validation_Data, 6)
# Out:
# 預測所花費時間：0小時0分鐘7秒

# %%
Preprocessing.Compute_Accuracy(Validation_Data, 6)
# Out:
#    Prediction  Match Percentage
# 0      Action        100.000000
# 1    length_6         52.240896
# 2    Filter_6         52.100840
# 3   length_12         49.579832
# 4   Filter_12         52.100840
# 5   length_18         47.829132
# 6   Filter_18         49.719888
# 7   length_24         47.058824
# 8   Filter_24         48.109244
# 9   length_30         46.848739
# 10  Filter_30         48.459384

# %%
Preprocessing.Test_Vomm(DataSet, 6)
# Out:
# 預測所花費時間：0小時1分鐘15秒

# %%
Preprocessing.Compute_Accuracy(DataSet, 6)
# Out:
#    Prediction  Match Percentage
# 0      Action        100.000000
# 1    length_6         68.337323
# 2    Filter_6         69.333539
# 3   length_12         63.707622
# 4   Filter_12         68.549695
# 5   length_18         62.479728
# 6   Filter_18         65.862229
# 7   length_24         62.082014
# 8   Filter_24         64.676809
# 9   length_30         62.568538
# 10  Filter_30         64.198008
